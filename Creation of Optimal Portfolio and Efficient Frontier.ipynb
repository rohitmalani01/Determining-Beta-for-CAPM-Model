# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
funds_data = pd.read_excel('Desktop/Mutual_Funds_Sht_list20.xlsx')

# %%
funds_data.set_index('Date', inplace=True)

# %%
funds_data
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# Date
# 2020-04-17             124.39             132.46             125.93
# 2020-04-24             124.39             132.46             125.93
# 2020-05-01             125.93             132.19             126.97
# 2020-05-08             125.93             132.19             126.97
# 2020-05-15             125.93             132.19             126.97
# ...                       ...                ...                ...
# 2022-01-14             182.56             175.93             166.95
# 2022-01-21             182.56             175.93             166.95
# 2022-01-28             182.56             175.93             166.95
# 2022-02-04             182.56             175.93             166.95
# 2022-02-11             182.56             175.93             166.95
#
#             PFARAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# Date
# ...

# %%
funds_data.describe()
# Out:
#        PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# count          96.000000          96.000000          96.000000
# mean          150.578229         150.462708         143.777187
# std            17.593980          13.319816          12.139749
# min           124.390000         132.190000         125.930000
# 25%           134.910000         139.305000         134.112500
# 50%           145.700000         147.110000         140.400000
# 75%           164.880000         160.812500         153.920000
# max           182.560000         175.930000         166.950000
#
#        PFARAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# count          96.000000          96.000000          96.000000
# mean          164.955208         115.235729         130.795833
# std            12.291321           8.566247           8.007520
# min           143.850000         101.570000         116.120000
# 25%           155.922500         108.870000         125.560000
# ...

# %%
funds_data_monthly = funds_data.resample('M').mean()
funds_data_monthly
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# Date
# 2020-04-30           124.3900            132.460           125.9300
# 2020-05-31           126.4140            132.606           127.3780
# 2020-06-30           128.3500            134.270           129.0100
# 2020-07-31           131.0100            137.234           130.9320
# 2020-08-31           133.3300            137.890           132.1000
# 2020-09-30           134.9300            139.170           134.1600
# 2020-10-31           135.7200            139.744           134.2640
# 2020-11-30           139.2000            141.320           135.4400
# 2020-12-31           141.4200            141.480           136.9700
# 2021-01-31           145.4520            144.630           139.7800
# 2021-02-28           144.9675            144.830           139.8275
# 2021-03-31           146.4900            147.110           141.5300
# 2021-04-30           147.0240            148.548           140.8160
# ...

# %%
funds_ret_monthly = funds_data_monthly.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
funds_ret_monthly
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# Date
# 2020-04-30                NaN                NaN                NaN
# 2020-05-31           0.016140           0.001102           0.011433
# 2020-06-30           0.015199           0.012470           0.012731
# 2020-07-31           0.020513           0.021835           0.014788
# 2020-08-31           0.017554           0.004769           0.008881
# 2020-09-30           0.011929           0.009240           0.015474
# 2020-10-31           0.005838           0.004116           0.000775
# 2020-11-30           0.025318           0.011215           0.008721
# 2020-12-31           0.015822           0.001132           0.011233
# 2021-01-31           0.028112           0.022020           0.020308
# 2021-02-28          -0.003337           0.001382           0.000340
# 2021-03-31           0.010448           0.015620           0.012102
# 2021-04-30           0.003639           0.009728          -0.005058
# ...

# %%
Annual_Ret = funds_ret_monthly.mean()*12
print (Annual_Ret)
# Out:
# PFGDAAU LX Equity    0.209268
# PFTEAAU LX Equity    0.154803
# PFCSAAU LX Equity    0.153801
# PFARAAU LX Equity    0.147682
# PFBKAAU LX Equity    0.139498
# PFGOAAU LX Equity    0.124115
# AIBALMA AB Equity    0.162475
# LODFUIA LX Equity    0.020113
# CCASORI MK Equity    0.075819
# CCASLTF MK Equity    0.074187
# BBFTOP3 KY Equity    0.058968
# CRLCBUU LX Equity    0.047142
# BCUSDLF KK Equity    0.006798
# GMFDEBI LE Equity    0.009815
# PGPGIFA ID Equity    0.061564
# BLUESPH BM Equity    0.055889
# PFGLAAU LX Equity    0.090129
# ALPCRDA LX Equity    0.090244
# ALCONGP AB Equity    0.052134
# UBSFLBI LX Equity    0.022696
# BUTIBLI KY Equity    0.142279
# PGPCBFA ID Equity    0.185265
# SCHGTRA LX Equity    0.093278
# dtype: float64

# %%
Annual_Risk = funds_ret_monthly.std()*(12)**(0.5)
print(Annual_Risk)
# Out:
# PFGDAAU LX Equity    0.050321
# PFTEAAU LX Equity    0.031564
# PFCSAAU LX Equity    0.039112
# PFARAAU LX Equity    0.038328
# PFBKAAU LX Equity    0.048561
# PFGOAAU LX Equity    0.051551
# AIBALMA AB Equity    0.038458
# LODFUIA LX Equity    0.004596
# CCASORI MK Equity    0.014155
# CCASLTF MK Equity    0.012955
# BBFTOP3 KY Equity    0.010702
# CRLCBUU LX Equity    0.010067
# BCUSDLF KK Equity    0.001154
# GMFDEBI LE Equity    0.005276
# PGPGIFA ID Equity    0.021470
# BLUESPH BM Equity    0.043417
# PFGLAAU LX Equity    0.028582
# ALPCRDA LX Equity    0.032349
# ALCONGP AB Equity    0.023559
# UBSFLBI LX Equity    0.010582
# BUTIBLI KY Equity    0.050889
# PGPCBFA ID Equity    0.127395
# SCHGTRA LX Equity    0.038893
# dtype: float64

# %%
Rf = 0.01
Sharpe_Ratio = (Annual_Ret - Rf)/Annual_Risk
Sharpe_Ratio
# Out:
# PFGDAAU LX Equity    3.959952
# PFTEAAU LX Equity    4.587617
# PFCSAAU LX Equity    3.676622
# PFARAAU LX Equity    3.592258
# PFBKAAU LX Equity    2.666718
# PFGOAAU LX Equity    2.213655
# AIBALMA AB Equity    3.964699
# LODFUIA LX Equity    2.200292
# CCASORI MK Equity    4.649791
# CCASLTF MK Equity    4.954449
# BBFTOP3 KY Equity    4.575676
# CRLCBUU LX Equity    3.689305
# BCUSDLF KK Equity   -2.773751
# GMFDEBI LE Equity   -0.035112
# PGPGIFA ID Equity    2.401651
# BLUESPH BM Equity    1.056942
# PFGLAAU LX Equity    2.803440
# ALPCRDA LX Equity    2.480574
# ALCONGP AB Equity    1.788501
# UBSFLBI LX Equity    1.199833
# BUTIBLI KY Equity    2.599374
# PGPCBFA ID Equity    1.375761
# SCHGTRA LX Equity    2.141221
# dtype: float64

# %%
Return_corr = funds_ret_monthly.corr()
Return_corr
# Out:
#                    PFGDAAU LX Equity  PFTEAAU LX Equity  PFCSAAU LX Equity  \
# PFGDAAU LX Equity           1.000000           0.549043           0.561688
# PFTEAAU LX Equity           0.549043           1.000000           0.786173
# PFCSAAU LX Equity           0.561688           0.786173           1.000000
# PFARAAU LX Equity           0.378933           0.736229           0.829603
# PFBKAAU LX Equity           0.366009           0.708881           0.879477
# PFGOAAU LX Equity           0.332684           0.464722           0.364484
# AIBALMA AB Equity          -0.077116          -0.169852          -0.166438
# LODFUIA LX Equity           0.005169           0.056646          -0.147685
# CCASORI MK Equity           0.118710           0.122450           0.028358
# CCASLTF MK Equity           0.183915           0.185481           0.098776
# BBFTOP3 KY Equity           0.068394           0.044921          -0.280483
# ...

# %%
# Highlighting the correlations
sns.set(rc={'figure.figsize':(21,21)})
sns.heatmap(Return_corr, cmap='rocket_r', vmin=0.5, annot=True, fmt='0.2f',linewidth=1, square=True)
# Out:
# <AxesSubplot:>

# %%
funds_data_new = funds_data.drop(columns=['PFCSAAU LX Equity', 'PFARAAU LX Equity', 'PFBKAAU LX Equity', 'CCASORI MK Equity', 'BCUSDLF KK Equity', 'GMFDEBI LE Equity', 'BLUESPH BM Equity', 'ALPCRDA LX Equity', 'UBSFLBI LX Equity', 'SCHGTRA LX Equity'])
funds_data_new
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  PFGOAAU LX Equity  \
# Date
# 2020-04-17             124.39             132.46             118.35
# 2020-04-24             124.39             132.46             118.35
# 2020-05-01             125.93             132.19             116.12
# 2020-05-08             125.93             132.19             116.12
# 2020-05-15             125.93             132.19             116.12
# ...                       ...                ...                ...
# 2022-01-14             182.56             175.93             148.59
# 2022-01-21             182.56             175.93             148.59
# 2022-01-28             182.56             175.93             148.59
# 2022-02-04             182.56             175.93             148.59
# 2022-02-11             182.56             175.93             148.59
#
#             AIBALMA AB Equity  LODFUIA LX Equity  CCASLTF MK Equity  \
# Date
# ...

# %%
funds_data_monthly_new = funds_data_new.resample('M').mean()
funds_data_monthly_new
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  PFGOAAU LX Equity  \
# Date
# 2020-04-30           124.3900            132.460           118.3500
# 2020-05-31           126.4140            132.606           116.5720
# 2020-06-30           128.3500            134.270           118.3800
# 2020-07-31           131.0100            137.234           122.0160
# 2020-08-31           133.3300            137.890           123.8000
# 2020-09-30           134.9300            139.170           126.3300
# 2020-10-31           135.7200            139.744           126.1520
# 2020-11-30           139.2000            141.320           125.5600
# 2020-12-31           141.4200            141.480           128.3400
# 2021-01-31           145.4520            144.630           131.7980
# 2021-02-28           144.9675            144.830           130.7175
# 2021-03-31           146.4900            147.110           130.6200
# 2021-04-30           147.0240            148.548           129.6720
# ...

# %%
funds_ret_monthly_new = funds_data_monthly_new.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
funds_ret_monthly_new
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  PFGOAAU LX Equity  \
# Date
# 2020-04-30                NaN                NaN                NaN
# 2020-05-31           0.016140           0.001102          -0.015137
# 2020-06-30           0.015199           0.012470           0.015391
# 2020-07-31           0.020513           0.021835           0.030252
# 2020-08-31           0.017554           0.004769           0.014515
# 2020-09-30           0.011929           0.009240           0.020230
# 2020-10-31           0.005838           0.004116          -0.001410
# 2020-11-30           0.025318           0.011215          -0.004704
# 2020-12-31           0.015822           0.001132           0.021899
# 2021-01-31           0.028112           0.022020           0.026587
# 2021-02-28          -0.003337           0.001382          -0.008232
# 2021-03-31           0.010448           0.015620          -0.000746
# 2021-04-30           0.003639           0.009728          -0.007284
# ...

# %%
Annual_Ret_new = funds_ret_monthly_new.mean()*12
print (Annual_Ret_new)
# Out:
# PFGDAAU LX Equity    0.209268
# PFTEAAU LX Equity    0.154803
# PFGOAAU LX Equity    0.124115
# AIBALMA AB Equity    0.162475
# LODFUIA LX Equity    0.020113
# CCASLTF MK Equity    0.074187
# BBFTOP3 KY Equity    0.058968
# CRLCBUU LX Equity    0.047142
# PGPGIFA ID Equity    0.061564
# PFGLAAU LX Equity    0.090129
# ALCONGP AB Equity    0.052134
# BUTIBLI KY Equity    0.142279
# PGPCBFA ID Equity    0.185265
# dtype: float64

# %%
Annual_Risk_new = funds_ret_monthly_new.std()*((12)**(0.5))
print(Annual_Risk_new)
# Out:
# PFGDAAU LX Equity    0.050321
# PFTEAAU LX Equity    0.031564
# PFGOAAU LX Equity    0.051551
# AIBALMA AB Equity    0.038458
# LODFUIA LX Equity    0.004596
# CCASLTF MK Equity    0.012955
# BBFTOP3 KY Equity    0.010702
# CRLCBUU LX Equity    0.010067
# PGPGIFA ID Equity    0.021470
# PFGLAAU LX Equity    0.028582
# ALCONGP AB Equity    0.023559
# BUTIBLI KY Equity    0.050889
# PGPCBFA ID Equity    0.127395
# dtype: float64

# %%
Return_corr_new = funds_ret_monthly_new.corr()
Return_corr_new
# Out:
#                    PFGDAAU LX Equity  PFTEAAU LX Equity  PFGOAAU LX Equity  \
# PFGDAAU LX Equity           1.000000           0.549043           0.332684
# PFTEAAU LX Equity           0.549043           1.000000           0.464722
# PFGOAAU LX Equity           0.332684           0.464722           1.000000
# AIBALMA AB Equity          -0.077116          -0.169852           0.120419
# LODFUIA LX Equity           0.005169           0.056646          -0.094640
# CCASLTF MK Equity           0.183915           0.185481           0.303980
# BBFTOP3 KY Equity           0.068394           0.044921          -0.026484
# CRLCBUU LX Equity          -0.076713           0.058456           0.311782
# PGPGIFA ID Equity           0.081223          -0.262058          -0.155643
# PFGLAAU LX Equity           0.335954           0.373941           0.482923
# ALCONGP AB Equity           0.325432           0.024494           0.007419
# ...

# %%
# Highlighting the correlations
sns.set(rc={'figure.figsize':(21,21)})
sns.heatmap(Return_corr_new, cmap='rocket_r', vmin=0.5, annot=True, fmt='0.2f',linewidth=1, square=True)
# Out:
# <AxesSubplot:>

# %%
# Log of percentage change and creeate Covariance matrix
Ret_cov_new = funds_data_new.pct_change().apply(lambda x: np.log(1+x)).cov()
Ret_cov_new
# Out:
#                    PFGDAAU LX Equity  PFTEAAU LX Equity  PFGOAAU LX Equity  \
# PFGDAAU LX Equity       1.441265e-04           0.000072       6.676647e-05
# PFTEAAU LX Equity       7.169259e-05           0.000056       4.612973e-05
# PFGOAAU LX Equity       6.676647e-05           0.000046       8.561887e-05
# AIBALMA AB Equity      -1.634953e-06           0.000005       1.012401e-05
# LODFUIA LX Equity       5.295693e-06           0.000004       3.212658e-06
# CCASLTF MK Equity      -4.956937e-06          -0.000004      -1.782542e-06
# BBFTOP3 KY Equity      -3.080687e-06          -0.000002      -1.169171e-06
# CRLCBUU LX Equity      -6.510476e-06          -0.000004       7.852111e-07
# PGPGIFA ID Equity      -4.431239e-07          -0.000001       4.453167e-07
# PFGLAAU LX Equity       1.972363e-05           0.000012       2.296136e-05
# ALCONGP AB Equity      -2.627961e-06          -0.000002       5.137174e-06
# ...

# %%
# Randomly weighted portfolio's variance
w = {'PFGDAAU LX Equity':0.0769, 'PFTEAAU LX Equity': 0.0769, 'PFGOAAU LX Equity': 0.0769, 'AIBALMA AB Equity': 0.0769,'LODFUIA LX Equity': 0.0769, 'CCASLTF MK Equity': 0.0769, 'BBFTOP3 KY Equity': 0.0769, 'CRLCBUU LX Equity': 0.0769,'PGPGIFA ID Equity': 0.0769, 'PFGLAAU LX Equity': 0.0769,'ALCONGP AB Equity': 0.0769, 'BUTIBLI KY Equity': 0.0769, 'PGPCBFA ID Equity': 0.0769}
pf_var = Ret_cov_new.mul(w, axis=0).mul(w, axis=1).sum().sum()
Annual_pf_std = (pf_var*12)**(0.5)
print ("Portfolio Variation is", pf_var)
print ("Portfolio Standard Deviation is", Annual_pf_std)
# Out:
# Portfolio Variation is 1.160163560308819e-05
# Portfolio Standard Deviation is 0.011799136715754178

# %%
# Portfolio returns
w = [0.0769, 0.0769, 0.0769, 0.0769, 0.0769, 0.0769, 0.0769, 0.0769, 0.0769, 0.0769, 0.0769, 0.0769, 0.0769]
port_er = (w*Annual_Ret_new).sum()
port_er
# Out:
# 0.1063097728699933

# %%
# Creating a table for visualising returns and volatility of assets
funds_view = pd.concat([Annual_Ret_new, Annual_Risk_new], axis=1) 
funds_view.columns = ['Returns', 'Volatility']
funds_view
# Out:
#                     Returns  Volatility
# PFGDAAU LX Equity  0.209268    0.050321
# PFTEAAU LX Equity  0.154803    0.031564
# PFGOAAU LX Equity  0.124115    0.051551
# AIBALMA AB Equity  0.162475    0.038458
# LODFUIA LX Equity  0.020113    0.004596
# CCASLTF MK Equity  0.074187    0.012955
# BBFTOP3 KY Equity  0.058968    0.010702
# CRLCBUU LX Equity  0.047142    0.010067
# PGPGIFA ID Equity  0.061564    0.021470
# PFGLAAU LX Equity  0.090129    0.028582
# ALCONGP AB Equity  0.052134    0.023559
# BUTIBLI KY Equity  0.142279    0.050889
# PGPCBFA ID Equity  0.185265    0.127395

# %%
import matplotlib.pyplot as plt
x = Annual_Risk_new # RISK
y = Annual_Ret_new # Return
plt.scatter(x, y)
plt.show()

# %%
p_ret = []               # Defining an empty array for portfolio returns
p_vol = []               # Defining an empty array for portfolio volatility
p_weights = []           # Defining an empty array for asset weights
num_assets = len(funds_data_new.columns)
num_portfolios = 11000
num_assets
# Out:
# 13

# %%
for portfolio in range(num_portfolios):
 weights = np.random.random(num_assets)
 weights = weights/np.sum(weights)
 p_weights.append(weights)
 returns = np.dot(weights, Annual_Ret_new) # Returns are the product of individual expected returns of asset and its 
 # weights 
 p_ret.append(returns)
 var = Ret_cov_new.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance
 sd = np.sqrt(var) #Daily standard deviation
 Annual_Risk_new = sd*np.sqrt(12) #Annual standard deviation = volatility
 p_vol.append(Annual_Risk_new)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}
for counter, symbol in enumerate(funds_data_new.columns.tolist()):
 #print(counter, symbol)
 data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#     Returns  Volatility  PFGDAAU LX Equity weight  PFTEAAU LX Equity weight  \
# 0  0.104964    0.010801                  0.168561                  0.091257
# 1  0.106272    0.014903                  0.094990                  0.048656
# 2  0.099333    0.012202                  0.019616                  0.180747
# 3  0.103288    0.011538                  0.005861                  0.112255
# 4  0.096203    0.012290                  0.017000                  0.105982
#
#    PFGOAAU LX Equity weight  AIBALMA AB Equity weight  \
# 0                  0.019345                  0.046234
# 1                  0.090591                  0.077467
# 2                  0.149064                  0.022954
# 3                  0.092172                  0.114604
# 4                  0.018138                  0.019716
#
#    LODFUIA LX Equity weight  CCASLTF MK Equity weight  \
# 0                  0.096461                  0.076813
# 1                  0.109517                  0.000417
# ...

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
#idxmin() gives us the minimum value in the column specified. 
min_vol_port
# Out:
# Returns                     0.078828
# Volatility                  0.006256
# PFGDAAU LX Equity weight    0.026785
# PFTEAAU LX Equity weight    0.032292
# PFGOAAU LX Equity weight    0.007112
# AIBALMA AB Equity weight    0.028470
# LODFUIA LX Equity weight    0.050165
# CCASLTF MK Equity weight    0.236532
# BBFTOP3 KY Equity weight    0.125059
# CRLCBUU LX Equity weight    0.207153
# PGPGIFA ID Equity weight    0.089968
# PFGLAAU LX Equity weight    0.059208
# ALCONGP AB Equity weight    0.053379
# BUTIBLI KY Equity weight    0.050679
# PGPCBFA ID Equity weight    0.033198
# Name: 5021, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[6,5])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %%
#  Plotting optimal portfolio
plt.subplots(figsize=(5, 6))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)

# %%
funds_data_new1 = funds_data_new.drop(columns=['PFGOAAU LX Equity', 'ALCONGP AB Equity', 'BUTIBLI KY Equity', 'PGPCBFA ID Equity'])
funds_data_new1
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  AIBALMA AB Equity  \
# Date
# 2020-04-17             124.39             132.46            16.6991
# 2020-04-24             124.39             132.46            16.8738
# 2020-05-01             125.93             132.19            16.6996
# 2020-05-08             125.93             132.19            16.8233
# 2020-05-15             125.93             132.19            16.9853
# ...                       ...                ...                ...
# 2022-01-14             182.56             175.93            22.6119
# 2022-01-21             182.56             175.93            22.5163
# 2022-01-28             182.56             175.93            22.5308
# 2022-02-04             182.56             175.93            22.6486
# 2022-02-11             182.56             175.93            22.5737
#
#             LODFUIA LX Equity  CCASLTF MK Equity  BBFTOP3 KY Equity  \
# Date
# ...

# %%
funds_data_monthly_new1 = funds_data_new1.resample('M').mean()
funds_data_monthly_new1
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  AIBALMA AB Equity  \
# Date
# 2020-04-30           124.3900            132.460          16.786450
# 2020-05-31           126.4140            132.606          17.007500
# 2020-06-30           128.3500            134.270          17.629050
# 2020-07-31           131.0100            137.234          18.079560
# 2020-08-31           133.3300            137.890          18.600525
# 2020-09-30           134.9300            139.170          18.864975
# 2020-10-31           135.7200            139.744          18.949640
# 2020-11-30           139.2000            141.320          19.156400
# 2020-12-31           141.4200            141.480          19.427050
# 2021-01-31           145.4520            144.630          19.728480
# 2021-02-28           144.9675            144.830          20.065475
# 2021-03-31           146.4900            147.110          20.328200
# 2021-04-30           147.0240            148.548          20.903620
# ...

# %%
funds_ret_monthly_new1 = funds_data_monthly_new1.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
funds_ret_monthly_new1
# Out:
#             PFGDAAU LX Equity  PFTEAAU LX Equity  AIBALMA AB Equity  \
# Date
# 2020-04-30                NaN                NaN                NaN
# 2020-05-31           0.016140           0.001102           0.013082
# 2020-06-30           0.015199           0.012470           0.035894
# 2020-07-31           0.020513           0.021835           0.025234
# 2020-08-31           0.017554           0.004769           0.028408
# 2020-09-30           0.011929           0.009240           0.014117
# 2020-10-31           0.005838           0.004116           0.004478
# 2020-11-30           0.025318           0.011215           0.010852
# 2020-12-31           0.015822           0.001132           0.014030
# 2021-01-31           0.028112           0.022020           0.015397
# 2021-02-28          -0.003337           0.001382           0.016937
# 2021-03-31           0.010448           0.015620           0.013008
# 2021-04-30           0.003639           0.009728           0.027913
# ...

# %%
Annual_Ret_new1 = funds_ret_monthly_new1.mean()*12
print (Annual_Ret_new1)
# Out:
# PFGDAAU LX Equity    0.209268
# PFTEAAU LX Equity    0.154803
# AIBALMA AB Equity    0.162475
# LODFUIA LX Equity    0.020113
# CCASLTF MK Equity    0.074187
# BBFTOP3 KY Equity    0.058968
# CRLCBUU LX Equity    0.047142
# PGPGIFA ID Equity    0.061564
# PFGLAAU LX Equity    0.090129
# dtype: float64

# %%
Annual_Risk_new1 = funds_ret_monthly_new1.std()*((12)**(0.5))
print(Annual_Risk_new1)
# Out:
# PFGDAAU LX Equity    0.050321
# PFTEAAU LX Equity    0.031564
# AIBALMA AB Equity    0.038458
# LODFUIA LX Equity    0.004596
# CCASLTF MK Equity    0.012955
# BBFTOP3 KY Equity    0.010702
# CRLCBUU LX Equity    0.010067
# PGPGIFA ID Equity    0.021470
# PFGLAAU LX Equity    0.028582
# dtype: float64

# %%
Return_corr_new1 = funds_ret_monthly_new1.corr()
Return_corr_new1
# Out:
#                    PFGDAAU LX Equity  PFTEAAU LX Equity  AIBALMA AB Equity  \
# PFGDAAU LX Equity           1.000000           0.549043          -0.077116
# PFTEAAU LX Equity           0.549043           1.000000          -0.169852
# AIBALMA AB Equity          -0.077116          -0.169852           1.000000
# LODFUIA LX Equity           0.005169           0.056646           0.204730
# CCASLTF MK Equity           0.183915           0.185481           0.427883
# BBFTOP3 KY Equity           0.068394           0.044921           0.213028
# CRLCBUU LX Equity          -0.076713           0.058456           0.225808
# PGPGIFA ID Equity           0.081223          -0.262058           0.401882
# PFGLAAU LX Equity           0.335954           0.373941           0.408361
#
#                    LODFUIA LX Equity  CCASLTF MK Equity  BBFTOP3 KY Equity  \
# PFGDAAU LX Equity           0.005169           0.183915           0.068394
# ...

# %%
# Log of percentage change and create Covariance matrix
Ret_cov_new1 = funds_data_new1.pct_change().apply(lambda x: np.log(1+x)).cov()
Ret_cov_new1
# Out:
#                    PFGDAAU LX Equity  PFTEAAU LX Equity  AIBALMA AB Equity  \
# PFGDAAU LX Equity       1.441265e-04           0.000072      -1.634953e-06
# PFTEAAU LX Equity       7.169259e-05           0.000056       4.866868e-06
# AIBALMA AB Equity      -1.634953e-06           0.000005       5.201934e-05
# LODFUIA LX Equity       5.295693e-06           0.000004       3.937103e-07
# CCASLTF MK Equity      -4.956937e-06          -0.000004       3.054655e-06
# BBFTOP3 KY Equity      -3.080687e-06          -0.000002      -6.997817e-09
# CRLCBUU LX Equity      -6.510476e-06          -0.000004       2.834879e-07
# PGPGIFA ID Equity      -4.431239e-07          -0.000001       5.832823e-06
# PFGLAAU LX Equity       1.972363e-05           0.000012       1.177909e-07
#
#                    LODFUIA LX Equity  CCASLTF MK Equity  BBFTOP3 KY Equity  \
# PFGDAAU LX Equity       5.295693e-06      -4.956937e-06      -3.080687e-06
# ...

# %%
# Randomly weighted portfolio's variance
w = {'PFGDAAU LX Equity': 0.11111, 'PFTEAAU LX Equity':0.11111, 'AIBALMA AB Equity': 0.11111,'LODFUIA LX Equity': 0.11111, 'CCASLTF MK Equity': 0.11111, 'BBFTOP3 KY Equity': 0.11111, 'CRLCBUU LX Equity': 0.11111,'PGPGIFA ID Equity': 0.11111, 'PFGLAAU LX Equity': 0.11111}
pf_var1 = Ret_cov_new1.mul(w, axis=0).mul(w, axis=1).sum().sum()
Annual_pf_std1 = (pf_var1*12)**(0.5)
print ("Portfolio Variation is", pf_var1)
print ("Portfolio Standard Deviation is", Annual_pf_std1)
# Out:
# Portfolio Variation is 6.265919610396751e-06
# Portfolio Standard Deviation is 0.008671276453023569

# %%
# Portfolio returns
w = [0.11111,0.11111,0.11111,0.11111,0.11111,0.11111,0.11111,0.11111,0.11111]
port_er1 = (w*Annual_Ret_new1).sum()
port_er1
# Out:
# 0.0976265765140747

# %%
# Creating a table for visualising returns and volatility of assets
funds_view1 = pd.concat([Annual_Ret_new1, Annual_Risk_new1], axis=1) 
funds_view1.columns = ['Returns', 'Volatility']
funds_view1
# Out:
#                     Returns  Volatility
# PFGDAAU LX Equity  0.209268    0.050321
# PFTEAAU LX Equity  0.154803    0.031564
# AIBALMA AB Equity  0.162475    0.038458
# LODFUIA LX Equity  0.020113    0.004596
# CCASLTF MK Equity  0.074187    0.012955
# BBFTOP3 KY Equity  0.058968    0.010702
# CRLCBUU LX Equity  0.047142    0.010067
# PGPGIFA ID Equity  0.061564    0.021470
# PFGLAAU LX Equity  0.090129    0.028582

# %%
import matplotlib.pyplot as plt
x = Annual_Risk_new1 # RISK
y = Annual_Ret_new1 # Return
plt.scatter(x,y)
plt.show()

# %%
p_ret1 = [] # Define an empty array for portfolio returns
p_vol1 = [] # Define an empty array for portfolio volatility
p_weights1 = [] # Define an empty array for asset weights
num_assets1 = len(funds_data_new1.columns)
num_portfolios = 10000

# %%
for portfolio in range(num_portfolios):
 weights1 = np.random.random(num_assets1)
 weights1 = weights1/np.sum(weights1)
 p_weights1.append(weights1)
 returns1 = np.dot(weights1, Annual_Ret_new1) # Returns are the product of individual expected returns of asset and its 
 # weights 
 p_ret1.append(returns1)
 var1 = Ret_cov_new1.mul(weights1, axis=0).mul(weights1, axis=1).sum().sum() # Portfolio Variance
 sd1 = np.sqrt(var1) #Daily standard deviation
 Annual_Risk_new1 = sd1*np.sqrt(12) #Annual standard deviation = volatility
 p_vol1.append(Annual_Risk_new1)

# %%
data1 = {'Returns':p_ret1, 'Volatility':p_vol1}
for counter, symbol in enumerate(funds_data_new1.columns.tolist()):
 #print(counter, symbol)
 data1[symbol+' weight1'] = [w[counter] for w in p_weights1]
portfolios1 = pd.DataFrame(data1)
portfolios1.head() # Dataframe of the 10000 portfolios created
# Out:
#     Returns  Volatility  PFGDAAU LX Equity weight1  PFTEAAU LX Equity weight1  \
# 0  0.089141    0.006683                   0.019740                   0.131219
# 1  0.102423    0.009854                   0.034121                   0.193781
# 2  0.097424    0.009918                   0.177227                   0.088830
# 3  0.098760    0.008731                   0.118158                   0.128295
# 4  0.118907    0.012497                   0.189447                   0.156566
#
#    AIBALMA AB Equity weight1  LODFUIA LX Equity weight1  \
# 0                   0.145639                   0.091938
# 1                   0.164317                   0.088070
# 2                   0.056958                   0.127151
# 3                   0.081158                   0.099527
# 4                   0.111357                   0.028660
#
#    CCASLTF MK Equity weight1  BBFTOP3 KY Equity weight1  \
# 0                   0.121112                   0.114216
# ...

# %%
# Plot efficient frontier
portfolios1.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
min_vol_port1 = portfolios1.iloc[portfolios1['Volatility'].idxmin()]
#idxmin() gives us the minimum value in the column specified. 
min_vol_port1
# Out:
# Returns                      0.057816
# Volatility                   0.003149
# PFGDAAU LX Equity weight1    0.020581
# PFTEAAU LX Equity weight1    0.007066
# AIBALMA AB Equity weight1    0.022787
# LODFUIA LX Equity weight1    0.204522
# CCASLTF MK Equity weight1    0.138368
# BBFTOP3 KY Equity weight1    0.263998
# CRLCBUU LX Equity weight1    0.180579
# PGPGIFA ID Equity weight1    0.152477
# PFGLAAU LX Equity weight1    0.009621
# Name: 3399, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[6,5])
plt.scatter(portfolios1['Volatility'], portfolios1['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port1[1], min_vol_port1[0], color='r', marker='*', s=200)

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port1 = portfolios1.iloc[((portfolios1['Returns']-rf)/portfolios1['Volatility']).idxmax()]
optimal_risky_port1
# Out:
# Returns                      0.065076
# Volatility                   0.003449
# PFGDAAU LX Equity weight1    0.028065
# PFTEAAU LX Equity weight1    0.015905
# AIBALMA AB Equity weight1    0.058056
# LODFUIA LX Equity weight1    0.222883
# CCASLTF MK Equity weight1    0.185611
# BBFTOP3 KY Equity weight1    0.283410
# CRLCBUU LX Equity weight1    0.092614
# PGPGIFA ID Equity weight1    0.078712
# PFGLAAU LX Equity weight1    0.034744
# Name: 230, dtype: float64

# %%
#  Plotting optimal portfolio - indicated by a Green star
plt.subplots(figsize=(5, 6))
plt.scatter(portfolios1['Volatility'], portfolios1['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port1[1], min_vol_port1[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port1[1], optimal_risky_port1[0], color='g', marker='*', s=500)
